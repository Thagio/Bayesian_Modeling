# %% [markdown]
# ## 以下のリンクを参考にPyMc3をお試し
# ## https://gaiasky.hatenablog.com/entry/2018/08/14/215145

# %%
# ライブラリの読み込み
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pymc3 as pm

# %matplotlib inline
# Out:
# /home/taichih34/anaconda3/lib/python3.7/site-packages/theano/configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# GPUを積んてない環境でためしているので、PyMC3のライブラリインポート時にWarningが出る

# %%
# 2枚のコインのデータを生成する。
n = 100 # コイン投げ回数
trials1 = stats.bernoulli.rvs(0.5, size=n)
trials2 = stats.bernoulli.rvs(0.55, size=n) #コイン2の方が表がちょっと出やすい。
h1 = sum(trials1)
h2 = sum(trials2)

# 最尤推定
print(h1/n, h2/n)
# Out:
# 0.43 0.59

# %%
# pymc3によるモデル化
with pm.Model() as model:
    p1 = pm.Uniform('p1', lower=0.0, upper=1.0)
    y1 = pm.Binomial('y1', n=n, p=p1, observed=h1)
    
    p2 = pm.Uniform('p2', lower=0.0, upper=1.0)
    y2 = pm.Binomial('y2', n=n, p=p2, observed=h2)
    # 2枚目のコインと1枚目のコインの差
    delta = pm.Deterministic('delta', p2-p1)

# モデルのグラフィカル表示（3.5から追加された機能）
pm.model_to_graphviz(model)
# Out:
# Warning: Could not load "/home/taichih34/anaconda3/lib/graphviz/libgvplugin_pango.so.6" - file not found

# %%
# MCMCの実行
with model:
    trace = pm.sample(2000, tune=500, step=pm.NUTS())
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [p2, p1]
# Sampling 2 chains: 100%|██████████| 5000/5000 [00:15<00:00, 318.56draws/s]

# %%
# 収束チェック
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f70945142e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f708ef94c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f70940c7710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f708ef60ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f708ef0eac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f708eebf9e8>]],
#       dtype=object)

# %%
# 結果の出力
pm.summary(trace)
# Out:
#            mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff      Rhat
# p1     0.430476  0.049300  0.000703  0.335519  0.523943  4359.333308  0.999838
# p2     0.588636  0.047921  0.000823  0.494588  0.678153  4232.132297  0.999818
# delta  0.158159  0.069523  0.001054  0.022658  0.295166  4375.805604  0.999751

# %%
# delta>0の確率は？
sum(trace['delta'] > 0)/len(trace['delta'])
# Out:
# 0.98675
